# %% [markdown]
# # Question 1
#
# 用coursework_other.csv，此数据集包括从一个联合循环电厂收集的6年（2006-2011）的数据。特征包括每小时平均环境变量温度（T）、环境压力（AP）、相对湿度（RH）和排气真空（V），以预测电厂每小时的净电能输出（PE）。你的任务是预测工厂每小时的净能量（PE）。
#
# 你要从以下几点出发来搞：
#
#  - 该用哪种算法：分类，回归，聚类
#  - 要用什么metric衡量模型的性能
#  - 你要用什么基础方法作为被对比的对象（sklearn.dummy里有很多备选）
#  - 怎么选择模型的超参数
#  - 怎么测试模型的表现

# %% [markdown]
# 具体来说，你应该使用scikit-learn的两种算法，并比较它们在数据集上的表现。你还应该将你选择的模型的性能与基线进行比较--即一个简单的模型，更复杂的模型应该能够战胜它。sklearn有一个模块sklearn.dummy，在生成基线时可能很有用。你应该使用技术来评估模型对未见过的数据的概括能力，并确保你对模型性能的评估是可靠的。

# %% [markdown]
# 在这里，工作表13、14和16中的材料将是有帮助的。 你对这个问题的回答应该采取简短报告的形式（最多4页），连同注释代码，详细说明你将采取的方法。确保你能解决上面所有的要点，并解释你的决定。例如："我选择使用X算法是因为Y"。因为Z，我使用了M指标"。你应该适当地使用图表来说明你的决定。 代码不会被标记为优雅，但它应该正确地运行。如果你使用的是jupyter，一个好的提示是确保你已经重新启动了内核，并确保代码在提交之前可以从头开始运行。

# %% [markdown]
# ## 打分标准
#
#  - (5分）报告的整体表述，包括使用适当的章节、图画、图表或表格来说明你的观点。请不要在报告中加入代码片段。相反，要用文字或方程式来描述你所实现的内容。方程格式要正确。
#  - (3分）选择一个合适的算法类型（分类/回归/聚类）并说明这一选择的理由。第13周的讲座和工作表在这里会有帮助。
#  - (3分）适当地选择性能指标（如：准确度/精确度/平均平方误差等）并说明理由。第13周的讲座和工作表在这里会有帮助。
#  - (4分) 讨论与之比较的基线种类。(sklearn有一个模块sklearn.dummy，在生成基线时可能是有用的)
#  - (10分) 使用适当的方法来选择所选算法的超参数。在解释选择哪些超参数时，应该用例如表格和图表来证明选择了哪些超参数值以及为什么。请至少选择一个使用超参数的模型，这样你就可以展示你在这个领域的知识。如果你选择了一个没有超参数的模型，那么请用几句话解释选择没有超参数的模型的好处是什么。第13周的讲座和工作表在这里会有帮助

# %% [markdown]
# ## 部分分解
#
#   - 2分：显示你了解什么是超参数以及如何选择它们
#   - 3分：看看不同的超参数选择对你的模型性能的影响
#   - 4分：用表格、图示或其他表现形式展示不同的超参数选择对模型性能的影响
#   - 1分：说明你所做的选择和原因
#   - 10分：训练和测试模型的性能，以显示模型是否能够归纳到未见过的数据，并确保模型的性能是鲁棒的。第13周的讲座和工作表在这里会有帮助。
#     - 4分：训练模型并选择超参数，以获得稳健的性能
#     - 3分：测试你的模型的性能并比较其性能
#     - 3分：确保对你的模型进行测试，以显示它们是否能够推广到未见过的数据
#   - 5分：分析你的结果。可以得出什么结论？

# %% [markdown]
# ## 推荐的报告结构
#
# 报告长度要求不差后果四页。短可以。
#
#  - Introduction：说明问题是什么。说明需要使用哪种算法（分类/回归/聚类），并解释为什么需要使用该种算法。
#  - Methods：:说明你将使用哪些具体的算法。说明你将使用哪种性能指标及原因。说明你将用什么基线来衡量你的算法。描述你将如何选择算法的超参数。解释你为每个模型选择了哪些超参数，用表格或图表来说明你的决定。
#  - Results and Analysis：报告你的模型的结果。适当地使用表格或图表来说明你的结果。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 2
#
# 国家和转型数据集可在[此处](http://web.mit.edu/phillipi/Public/states_and_transformations/index.html)，并在论文Isola等人[2015]中描述。注意：你不需要阅读整篇论文。在黑板上提供的模板中提供对数据表问题的回答。数据表在Gebru等人[2021]的论文中描述，可在https://arxiv.org/abs/1803.09010。

# %% [markdown]
# ## 打分标准
#
#  - Section 3.2 Composition 5分
#  - Section 3.3 Collection Process 3分
#  - Section 3.5 Uses 2分
#
# 黑板上有一个只包含相关问题的模板。 第17周的工作表在这里会有帮助。数据表的例子也可以在论文的附录中看到。
